# %%
logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""


from IPython.display import clear_output
import random


# Making functions.

# shuffiling deck and removing 1 card and dealing it.
def deal_card(user):
    random.shuffle(cards)
    card = cards.pop()
    user.append(card)

#converting 11 to 1 if criteria is met.
def ace_to_one(user):
    count = 0
    for n in user:
        if sum(user) > 21 and n==11:
            user[count] = 1
        count += 1

# with chipa i mean player chips and beta means player's bet.
# Win / lose / draw scenarios, i RETURN chips.
def win_lose_check(chipa,beta):
    
    if computer_score > player_score and computer_score < 22:
        clear_output()
        print(logo)
        print(f"\nYour hand is {player}, current score: {player_score}")
        print(f"Dealer hand is {computer}, current score: {computer_score}")
        print("Dealer WINS")
        chipa -= beta
        

    elif player_score > computer_score and player_score < 22:
        clear_output()
        print(logo)
        print(f"\nYour hand is {player}, current score: {player_score}")
        print(f"Dealer hand is {computer}, current score: {computer_score}")
        print("Player WINS")
        chipa += beta
        

    elif player_score > 21:
        clear_output()
        print(logo)
        print(f"\nYour hand is {player}, current score: {player_score}")
        print(f"Dealer hand is {computer}, current score: {computer_score}")
        print("Player BUSTS, Dealer WINS")
        chipa -= beta
        

    elif computer_score > 21:
        clear_output()
        print(logo)
        print(f"\nYour hand is {player}, current score: {player_score}")
        print(f"Dealer hand is {computer}, current score: {computer_score}")
        print("Dealer BUSTS, Player WINS")
        chipa += beta
        
    
    elif computer_score == player_score and player_score == 21 and computer_score == 21:
        print(logo)
        print(f"\nYour hand is {player}, current score: {player_score}")
        print(f"Dealer hand is {computer}, current score: {computer_score}")
        print("Both the Dealer and Player have BLACKJACK!, but Dealer wins :(")
        chipa -= beta
        

    elif computer_score == player_score:
        clear_output()
        print(logo)
        print(f"\nYour hand is {player}, current score: {player_score}")
        print(f"Dealer hand is {computer}, current score: {computer_score}")
        print("Its a DRAW!")
        chipa = chipa
        
    else:
        clear_output()
        print(logo)
        print("Logic Error")
    
    print(f"You have ${chipa} remaining!")
    return chipa

#-------------------------------------------------------------------------------------------------------------
# Start of Blackjack game logic
        
playing = input("Do you want to play a game of blackjack? (Y/N): ").upper()

if playing == "Y":
    playing = True
else:
    playing = False

rounda = 0
player_chips = 0

while playing:
    
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]*4
    
    # Asking how much chips player wants to buy in round 1, asking for bet, and giving cards to player/dealer.
    
    print(logo)
    
    chips = True
    while chips and rounda == 0:
        try:
            player_chips = int(input("How many chips do you want to buy?: $"))
        except:
            print("Thats not a valid number")
            continue
        else:
            chips = False
    
    bet = True
    while bet:
        
        try:
            print(f"You have ${player_chips} remaining!")
            player_bet = int(input("How much do you want to bet?: $"))
            
            if player_bet > player_chips:
                print("You dont have enough chips to make that bet")
                continue
        except:
            print("Thats not a valid number")
            continue
        else:
            bet = False
    

    player = []
    computer = []

    deal_card(player)
    deal_card(player)
    deal_card(computer)
    deal_card(computer)
    ace_to_one(player)
    ace_to_one(computer)

    player_score = sum(player)
    computer_score = sum(computer)

    print(f"\nYour hand is {player}, current score: {player_score}")
    print(f"\nDealer first card is: {computer[0]}")

    player_turn = True
    computer_turn = True
    
    #Player turn
    
    while player_turn:
        
        if player_score > 21:
            player_turn = False
            computer_turn = False
        
        if not player_score > 21:
            player_choice = input("\nType 'Y' to get another card, type 'N' to pass ").upper()
        
        if player_choice not in ["Y","N"]:
            continue
            
        if player_choice == "Y" and player_score < 22:
            deal_card(player)
            ace_to_one(player)
            player_score = sum(player)
            print(f"Your hand is {player}, current score: {player_score}")
            continue
        else:
            player_turn = False
            
    # Dealer Turn
    
    while computer_turn:
        
        if computer_score >= 17:
            computer_turn = False
        
        elif computer_score <= 16:
            deal_card(computer)
            ace_to_one(computer)
            computer_score = sum(computer)
    
   
    # Checking for winner and updating chips.
    player_chips = win_lose_check(player_chips,player_bet)
    
    
    
    # Asking if player wants to play another hand or stopping game if chips = 0.
    run = True
    other_hand = "N"
    while run and player_chips>0:
        other_hand = input("\nDo you want to play another hand? (Y/N): ").upper()
        if other_hand not in ["Y","N"]:
            print("Please choose 'Y' or 'N'")
            continue
        else:
            run = False
    if player_chips <= 0:
        playing = False
    
    if other_hand == "Y":
        clear_output()
        rounda += 1
    else:
        playing = False
# Out:
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
#
# Your hand is [10, 5, 1], current score: 16
# Dealer hand is [9, 6, 6], current score: 21
# Dealer WINS
# You have $3000 remaining!
#
# Do you want to play another hand? (Y/N): n
